# %%
import pandas as pd
df = pd.read_csv('FMKOREA_쿠팡_.csv', names=['title','user_id','post_time','post','reply_cnt','reply_author','reply_content','reply_date'])
df=df.drop(0)
df
# Out:
#                                   title   user_id         post_time  \
# 1             쿠팡이 잘되는 이유는 트렌드를 너무 잘 아는듯  ICUWALKS  2024.05.22 21:31
# 2             쿠팡이 잘되는 이유는 트렌드를 너무 잘 아는듯  ICUWALKS  2024.05.22 21:31
# 3             쿠팡이 잘되는 이유는 트렌드를 너무 잘 아는듯  ICUWALKS  2024.05.22 21:31
# 4             쿠팡이 잘되는 이유는 트렌드를 너무 잘 아는듯  ICUWALKS  2024.05.22 21:31
# 5                 조축 보려고쿠팡켰는데 왠 토트넘 경기가   손흥민은득점왕  2024.05.22 19:28
# ...                                 ...       ...               ...
# 12749  아니 티비앤스포츠를 틀어서 봐라게이들아쿠팡그거 계속터짐ㅇㅇ   홍명보울산종신  2024.01.14 22:10
# 12750                    쿠팡내일 감당 가능하냐;;      망스터치  2024.01.14 22:10
# 12751                             아쿠팡씨발      고기국수  2024.01.14 22:09
# 12752                             아쿠팡씨발      고기국수  2024.01.14 22:09
# 12753                             아쿠팡씨발      고기국수  2024.01.14 22:09
#
#                                         post reply_cnt reply_author  \
# 1      시발 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ         4         커피콜라
# ...

# %%
df['reply_cnt'].unique()
# Out:
# array(['4', '3', '2', '14', '1', '6', '0', '10', '17', '8', '11', '16',
#        '502', '20', '5', '13', '61', '7', '12', '9', '18', '15', '41',
#        '22', '21', '24', '39', '30', '19', '23', '28', '343', '43', '25',
#        '140', '44', '154', '33', '303', '34', '32', '323', '126', '35',
#        '65', '27', '57', '38', '29', '37', '69', 'reply_cnt', '271',
#        '180', '358', '246', '76', '102'], dtype=object)

# %%
df['reply_cnt'] = pd.to_numeric(df['reply_cnt'], errors='coerce')
df[df['reply_cnt']>=50]['title'].unique()
# Out:
# array(['(오피셜)토트넘 뮌헨 8/3 서울월드컵 스타디움', '5/18 K리그 라인업',
#        '[단독]쿠팡플레이, 英 프리미어리그 2025·26시즌부터 6년 독점 중계권 따내 총 6년 계약… 1년 중계료로 700억원 지급 예정',
#        '[오피셜] 어린이날 연휴 서울 vs 울산 지상파, 연맹, 쿠플픽 중계진 확정',
#        '[오피셜] 서울 vs 포항 지상파, 쿠플픽, 연맹 중계진 확정',
#        '[오피셜] 대한민국 vs 태국 TV,쿠팡플레이 중계진', '[오피셜]김수빈 이스타와 이별',
#        '프리킥 벽 거리도 설정 못하는 심판. 물음표 생기는  ‘기본 능력’',
#        '수 년간 상암 직관 따라와주던 여자친구가 어제 경기 보고 앞으론 직관 절대 가지 말고 쿠플로 보자하네요...',
#        'K리그는 2018년까지만 해도 세련된 이미지라고는 단 하나도 없는 똥꾸릉내 오지게 나는 리그였음.',
#        '[정보] 다음주 서울v인천 MBC,쿠팡플레이 중계진 떴다 ㄷㄷㄷㄷㄷㄷㄷㄷ',
#        '30살 인생 처음으로 K리그 중계를 본 후기 (서울vs광주)',
#        '개그맨 이경규,쿠팡플레이 K리그 개막전 중계 객원 해설', '[단독] 손흥민 차고 김민재 막는 장면, 한국서 본다',
#        '클린스만의 343이 공격이 안된 이유 (대한민국 사우디 분석)', '23년도 축구직관 인증!',
#        '쿠팡플레이 중국전 하이라이트 썸네일 짤 선정 죽이네 ㅋㅋㅋ'], dtype=object)

# %%
df
# Out:
#                                   title   user_id         post_time  \
# 1             쿠팡이 잘되는 이유는 트렌드를 너무 잘 아는듯  ICUWALKS  2024.05.22 21:31
# 2             쿠팡이 잘되는 이유는 트렌드를 너무 잘 아는듯  ICUWALKS  2024.05.22 21:31
# 3             쿠팡이 잘되는 이유는 트렌드를 너무 잘 아는듯  ICUWALKS  2024.05.22 21:31
# 4             쿠팡이 잘되는 이유는 트렌드를 너무 잘 아는듯  ICUWALKS  2024.05.22 21:31
# 5                 조축 보려고쿠팡켰는데 왠 토트넘 경기가   손흥민은득점왕  2024.05.22 19:28
# ...                                 ...       ...               ...
# 12749  아니 티비앤스포츠를 틀어서 봐라게이들아쿠팡그거 계속터짐ㅇㅇ   홍명보울산종신  2024.01.14 22:10
# 12750                    쿠팡내일 감당 가능하냐;;      망스터치  2024.01.14 22:10
# 12751                             아쿠팡씨발      고기국수  2024.01.14 22:09
# 12752                             아쿠팡씨발      고기국수  2024.01.14 22:09
# 12753                             아쿠팡씨발      고기국수  2024.01.14 22:09
#
#                                         post  reply_cnt reply_author  \
# 1      시발 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ        4.0         커피콜라
# ...

# %%
titles_to_drop = ['(오피셜)토트넘 뮌헨 8/3 서울월드컵 스타디움', '5/18 K리그 라인업',
       '[단독]쿠팡플레이, 英 프리미어리그 2025·26시즌부터 6년 독점 중계권 따내 총 6년 계약… 1년 중계료로 700억원 지급 예정',
       '[오피셜] 어린이날 연휴 서울 vs 울산 지상파, 연맹, 쿠플픽 중계진 확정',
       '[오피셜] 서울 vs 포항 지상파, 쿠플픽, 연맹 중계진 확정',
       '[오피셜] 대한민국 vs 태국 TV,쿠팡플레이 중계진', '[오피셜]김수빈 이스타와 이별',
       '프리킥 벽 거리도 설정 못하는 심판. 물음표 생기는  ‘기본 능력’',
       '수 년간 상암 직관 따라와주던 여자친구가 어제 경기 보고 앞으론 직관 절대 가지 말고 쿠플로 보자하네요...',
       'K리그는 2018년까지만 해도 세련된 이미지라고는 단 하나도 없는 똥꾸릉내 오지게 나는 리그였음.',
       '[정보] 다음주 서울v인천 MBC,쿠팡플레이 중계진 떴다 ㄷㄷㄷㄷㄷㄷㄷㄷ']

# %%
# title 컬럼의 값이 titles_to_drop에 포함되지 않은 행들만 남기기
df_filtered = df[~df['title'].isin(titles_to_drop)]
df_filtered
# Out:
#                                   title   user_id         post_time  \
# 1             쿠팡이 잘되는 이유는 트렌드를 너무 잘 아는듯  ICUWALKS  2024.05.22 21:31
# 2             쿠팡이 잘되는 이유는 트렌드를 너무 잘 아는듯  ICUWALKS  2024.05.22 21:31
# 3             쿠팡이 잘되는 이유는 트렌드를 너무 잘 아는듯  ICUWALKS  2024.05.22 21:31
# 4             쿠팡이 잘되는 이유는 트렌드를 너무 잘 아는듯  ICUWALKS  2024.05.22 21:31
# 5                 조축 보려고쿠팡켰는데 왠 토트넘 경기가   손흥민은득점왕  2024.05.22 19:28
# ...                                 ...       ...               ...
# 12749  아니 티비앤스포츠를 틀어서 봐라게이들아쿠팡그거 계속터짐ㅇㅇ   홍명보울산종신  2024.01.14 22:10
# 12750                    쿠팡내일 감당 가능하냐;;      망스터치  2024.01.14 22:10
# 12751                             아쿠팡씨발      고기국수  2024.01.14 22:09
# 12752                             아쿠팡씨발      고기국수  2024.01.14 22:09
# 12753                             아쿠팡씨발      고기국수  2024.01.14 22:09
#
#                                         post  reply_cnt reply_author  \
# 1      시발 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ        4.0         커피콜라
# ...

# %%
df_filtered.to_csv('FMKOREA_쿠팡_filtered.csv', index=False)

# %%
df_1 = pd.read_csv('FMKOREA_쿠팡_filtered.csv')
df_2 = pd.read_csv('FMKOREA_쿠플_2.csv', header=None, names = ['title','user_id','post_time','post','reply_cnt','reply_author','reply_content','reply_date'])
df = pd.concat([df_1,df_2])
df = df.reset_index()
df.to_csv('FMKOREA_쿠팡_.csv', index=False)

# %%
import pandas as pd
df_1 = pd.read_csv('fmkorea_crawling/FMKOREA_쿠플_0.csv', header=None, names=['title','user_id','post_time','post','reply_cnt','reply_author','reply_content','reply_date'])
df_1 = df_1.iloc[1:]
df_2 = pd.read_csv('fmkorea_crawling\FMKOREA_쿠플_1.csv', header=None, names = ['title','user_id','post_time','post','reply_cnt','reply_author','reply_content','reply_date'])
df_2 = df_2.iloc[1:]
df_3 = pd.read_csv('fmkorea_crawling\FMKOREA_쿠플_2.csv', header=None, names = ['title','user_id','post_time','post','reply_cnt','reply_author','reply_content','reply_date'])
df_3
df_3 = df_3.iloc[1:]
df_4 = pd.read_csv('fmkorea_crawling\FMKOREA_쿠플_3.csv', header=None, names = ['title','user_id','post_time','post','reply_cnt','reply_author','reply_content','reply_date'])
df_4
df_4 = df_4.iloc[1:]
df_5 = pd.read_csv('fmkorea_crawling\FMKOREA_쿠플_4.csv', header=None, names = ['title','user_id','post_time','post','reply_cnt','reply_author','reply_content','reply_date'])
df_5
df_5 = df_5.iloc[1:]
df_concat = pd.concat([df_1, df_2, df_3, df_4, df_5])
df_concat = df_concat.reset_index()
df_concat.to_csv('FMKOREA_쿠플.csv', index=False)

# %%
pd.read_csv('FMKOREA_쿠팡.csv')
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_29240\801796917.py:1: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv('FMKOREA_쿠팡.csv')
#        level_0  index                       title   user_id         post_time  \
# 0            0    0.0   쿠팡이 잘되는 이유는 트렌드를 너무 잘 아는듯  ICUWALKS  2024.05.22 21:31
# 1            1    1.0   쿠팡이 잘되는 이유는 트렌드를 너무 잘 아는듯  ICUWALKS  2024.05.22 21:31
# 2            2    2.0   쿠팡이 잘되는 이유는 트렌드를 너무 잘 아는듯  ICUWALKS  2024.05.22 21:31
# 3            3    3.0   쿠팡이 잘되는 이유는 트렌드를 너무 잘 아는듯  ICUWALKS  2024.05.22 21:31
# 4            4    4.0       조축 보려고쿠팡켰는데 왠 토트넘 경기가   손흥민은득점왕  2024.05.22 19:28
# ...        ...    ...                         ...       ...               ...
# 79619    13818    NaN           쿠팡플레이가 tv보다 4분느리네     발달린케인  2021.06.09 20:08
# 79620    13819    NaN           쿠팡플레이가 tv보다 4분느리네     발달린케인  2021.06.09 20:08
# ...

# %%
import pandas as pd
a = pd.read_csv('fmkorea_crawling/FMKOREA_쿠팡.csv')
a.shape
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_29240\1842618359.py:2: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   a = pd.read_csv('fmkorea_crawling/FMKOREA_쿠팡.csv')
# (79624, 10)

# %%
len(a['title'].unique())
# Out:
# 9874

# %%
import pandas as pd
a = pd.read_csv('fmkorea_crawling/FMKOREA_쿠플.csv')
a.shape
# Out:
# (35009, 9)

# %%
# 두 개의 CSV 파일을 불러와서 데이터프레임으로 변환
df_coupang = pd.read_csv('fmkorea_crawling/FMKOREA_쿠팡.csv')
df_couple = pd.read_csv('fmkorea_crawling/FMKOREA_쿠플.csv')

# title 열을 기준으로 겹치는 행 제거
df_couple = df_couple[~df_couple['title'].isin(df_coupang['title'])]
df_couple
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_29596\4022461611.py:2: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_coupang = pd.read_csv('fmkorea_crawling/FMKOREA_쿠팡.csv')
#        index                                              title  user_id  \
# 0          1                               일본에서쿠플볼 수 있는 방법 있나여?      공차고
# 1          2                               일본에서쿠플볼 수 있는 방법 있나여?      공차고
# 2          3                               일본에서쿠플볼 수 있는 방법 있나여?      공차고
# 3          4                               일본에서쿠플볼 수 있는 방법 있나여?      공차고
# 4          5  근데 브이로거들 증에 경기 장면을 찍는 브이로거들도 있고 안찍는 브이로거들도 있는데...  양민혁은터진다
# ...      ...                                                ...      ...
# 35004   7340                        쿠플k리그의 자존심 문구 별거 없는데 종나 뽕차네      흥명보
# 35005   7341                                       쿠플로 프리뷰쇼 보는데  서울노원Fan
# 35006   7342                                          진짜 쿠팡개혜자다  수원종합운동장
# ...

# %%
df_coupang
# Out:
#        level_0  index                       title   user_id         post_time  \
# 0            0    0.0   쿠팡이 잘되는 이유는 트렌드를 너무 잘 아는듯  ICUWALKS  2024.05.22 21:31
# 1            1    1.0   쿠팡이 잘되는 이유는 트렌드를 너무 잘 아는듯  ICUWALKS  2024.05.22 21:31
# 2            2    2.0   쿠팡이 잘되는 이유는 트렌드를 너무 잘 아는듯  ICUWALKS  2024.05.22 21:31
# 3            3    3.0   쿠팡이 잘되는 이유는 트렌드를 너무 잘 아는듯  ICUWALKS  2024.05.22 21:31
# 4            4    4.0       조축 보려고쿠팡켰는데 왠 토트넘 경기가   손흥민은득점왕  2024.05.22 19:28
# ...        ...    ...                         ...       ...               ...
# 79619    13818    NaN           쿠팡플레이가 tv보다 4분느리네     발달린케인  2021.06.09 20:08
# 79620    13819    NaN           쿠팡플레이가 tv보다 4분느리네     발달린케인  2021.06.09 20:08
# 79621    13820    NaN           쿠팡플레이가 tv보다 4분느리네     발달린케인  2021.06.09 20:08
# 79622    13821    NaN           쿠팡플레이가 tv보다 4분느리네     발달린케인  2021.06.09 20:08
# 79623    13822    NaN  보니까 PC 플랫폼이랑 계약을 안했나본데 ㅋㅋㅋ       카펠라  2021.06.09 20:07
#
# ...

# %%
fmkorea = pd.concat([df_coupang, df_couple])
fmkorea.shape
# Out:
# (112903, 10)

# %%
fmkorea.to_csv('fmkorea.csv', index=False)

# %%
# 두 개의 CSV 파일을 불러와서 데이터프레임으로 변환
df_coupang = pd.read_csv('RS_쿠팡_posts.csv')
df_couple = pd.read_csv('RS_쿠플_posts.csv')
df_coupang_cmt = pd.read_csv('RS_쿠팡_comments.csv')
df_couple_cmt = pd.read_csv('RS_쿠플_comments.csv')

# %%
df_coupang_cmt.shape
# Out:
# (3752, 4)

# %%
# title 열을 기준으로 겹치는 행 제거
df_couple_cmt = df_couple_cmt[~df_couple_cmt['cmt_num'].isin(df_coupang_cmt['cmt_num'])]
df_couple_cmt.shape
# Out:
# (1514, 4)

# %%
RS_posts = pd.concat([df_coupang, df_couple])

# %%
RS_comments = pd.concat([df_coupang_cmt, df_couple_cmt])

# %%
RS_posts.to_csv('RS_posts.csv', index=False)
RS_comments.to_csv('RS_comments.csv', index=False)
