# %%
# 자동화하기
# 이어서 쓸 때 save_to_file과 append_to_file 함수에 mode의 파라미터를 'a'로 변경해보기
import requests
from bs4 import BeautifulSoup
from urllib.parse import urlencode
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from fake_useragent import UserAgent
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import TimeoutException
from selenium.webdriver.support import expected_conditions as EC
import time
from datetime import datetime
from selenium.webdriver.chrome.options import Options
import csv

# 변수 설정
QUERY = ''
search_QUERY = urlencode({'subquery': QUERY}, encoding='utf-8')
URL = f"https://mlbpark.donga.com/mp/b.php?p=1&m=search&b=kbotown&query=%EB%91%90%EC%82%B0&select=spf&{search_QUERY}&subselect=sct&user="

def get_posts(page_num):
    global QUERY
    posts = []
    for page in range(22, page_num + 1):
        # 페이지 넘기기
        board_link = f"https://mlbpark.donga.com/mp/b.php?p={30 * page+1}&m=search&b=kbotown&query=%EB%91%90%EC%82%B0&select=spf&{search_QUERY}&subselect=sct&user="
        req = requests.get(board_link)
        print(req.status_code)
        soup = BeautifulSoup(req.text, 'html.parser')
        # 전체 30개의 게시글의 링크를 posts에 append하는 과정
        tds = soup.find_all('td', {'class': 't_left'})
        for td in tds:
            post = td.find('a', {'class': 'txt'})
            if post is not None:
                posts.append(post['href'])
    print(f"총 {len(posts)}개의 글 링크를 찾았습니다.")
    # 게시글 링크 csv로 저장
    post_file = open(f"MLBPARK_{QUERY}_{page_num}pages_inner_links.csv", mode='w', encoding='utf-8')
    writer = csv.writer(post_file)
    for post in posts:
        writer.writerow([post])
    post_file.close()
    return posts

def extract_info(url):
    chrome_options = Options()
    chrome_options.add_argument('--headless')  # Headless 모드 활성화
    driver = webdriver.Chrome(options=chrome_options)
    driver.get(url)
    driver.get(url)
    html = driver.page_source
    driver.quit()
    soup = BeautifulSoup(html,'html.parser')
    site = soup.find('h1', {'class': 'logo'}).find('a').find('img')['title'].strip()
    title = soup.find('div', {'class': 'titles'}).get_text(strip=True)
    user_id = soup.find('span', {'class': 'nick'}).get_text(strip=True)
    post_time = soup.find('div', {'class': 'text3'}).find('span', {'class': 'val'}).get_text(strip=True) + ':00'
    post_time = datetime.strptime(post_time, '%Y-%m-%d %H:%M:%S')
    post = soup.find('div', {'id': 'contentDetail'}).get_text(strip=True)
    view_cnt = int(soup.find('div', {'class': 'text2'}).find_all('span', {'class': 'val'})[1].get_text(strip=True).replace('\n', '').replace('\r', '').replace(',', ''))
    recomm_cnt = int(soup.find('span', {'id': 'likeCnt'}).get_text(strip=True).replace('\n', '').replace('\r', '').replace(',', ''))
    reply_cnt = int(soup.find('span', {'id': 'replyCnt'}).get_text(strip=True).replace('\n', '').replace('\r', '').replace(',', ''))
    reply_content = []
    if reply_cnt != 0:
        replies = soup.find_all('div', {'class': 'txt_box'})
        for reply in replies:
            reply_author = reply.find('span', {'class': 'name'}).get_text(strip=True)
            reply_text = reply.find('span', {'class': 're_txt'}).get_text(strip=True).replace('\n', '').replace('\r', '').replace('\t', '')
            reply_content.append({'author': reply_author, 'text': reply_text})

    data = {'site': site, 'title': title, 'user_id': user_id, 'post_time': post_time, 'post': post, 'view_cnt': view_cnt,
            'recomm_cnt': recomm_cnt, 'reply_cnt': reply_cnt, 'reply_content': reply_content}

    # 댓글이 있다면 딕셔너리에 추가
    if reply_cnt != 0:
        for i, reply_info in enumerate(reply_content):
            data[f'reply_{i+1}_author'] = reply_info['author']
            data[f'reply_{i+1}_text'] = reply_info['text']

    print(url, '완료')
    return data

def get_contents(posts):
    for post_link in posts:
        content = extract_info(post_link)
        append_to_file(f"MLBPARK_{QUERY}_0228.csv", content)
    return print("모든 작업이 완료되었습니다.")

def save_to_file():
    file = open(f'MLBPARK_{QUERY}_0228.csv', mode='a', encoding='utf-8')
    writer = csv.writer(file)
    writer.writerow(['site', 'title', 'user_id', 'post_time', 'post', 'view_cnt', 'recomm_cnt', 'reply_cnt', 'reply_author', 'reply_content'])
    file.close()
    return file

def append_to_file(file_name, data):
    file = open(file_name, mode='a', encoding='utf-8', newline='')  # newline 추가
    writer = csv.writer(file)

    # Write main post data to CSV
    main_post_row = [
        data['site'],
        data['title'],
        data['user_id'],
        data['post_time'],
        data['post'],
        data['view_cnt'],
        data['recomm_cnt'],
        data['reply_cnt']
    ]

    # Check if there are replies
    if 'reply_content' in data and data['reply_cnt'] != 0:
        # Write main post data along with reply data to CSV
        for i, reply_info in enumerate(data['reply_content']):
            writer.writerow(main_post_row + [
                reply_info.get('author', ''),  # Reply author
                reply_info.get('text', '')  # Reply text
            ])
    else:
        # Write only main post data to CSV
        writer.writerow(main_post_row + ['']*2)

    file.close()
    return

# 크롤링할 페이지 수 설정
PAGES = 50
# 게시글 링크 수집
post_links = get_posts(PAGES)
# 결과를 저장할 CSV 파일 생성
save_to_file()
# 게시글 정보 크롤링 및 저장
get_contents(post_links)
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 총 870개의 글 링크를 찾았습니다.
# https://mlbpark.donga.com/mp/b.php?id=202402200089588376&p=661&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402200089587326&p=661&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402200089587143&p=661&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402200089586846&p=661&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402200089585028&p=661&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402200089584332&p=661&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402200089584053&p=661&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402200089581980&p=661&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402200089581221&p=661&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402200089581113&p=661&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402200089578833&p=661&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402190089574732&p=661&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402190089571960&p=661&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402190089566782&p=661&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402190089566737&p=661&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402190089563230&p=661&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402190089561427&p=661&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402190089560701&p=661&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402190089560221&p=661&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402190089559918&p=661&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402190089559720&p=661&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402190089557122&p=661&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402190089554602&p=661&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402190089554122&p=661&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402190089554086&p=661&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402180089552988&p=661&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402180089552331&p=661&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402180089552280&p=661&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402180089552127&p=661&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402180089550204&p=661&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402180089545155&p=691&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402180089544291&p=691&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402180089544237&p=691&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402180089544201&p=691&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402180089542815&p=691&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402180089541909&p=691&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402180089539140&p=691&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402180089538957&p=691&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402180089537598&p=691&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402180089537505&p=691&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402180089537496&p=691&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402180089537058&p=691&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402180089536410&p=691&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402180089535399&p=691&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402170089532213&p=691&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402170089529864&p=691&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402170089524944&p=691&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402170089524695&p=691&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402170089524659&p=691&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402170089521923&p=691&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402170089519943&p=691&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402170089519148&p=691&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402170089518578&p=691&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402170089517528&p=691&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402170089516007&p=691&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402170089515269&p=691&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402170089512770&p=691&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402160089511186&p=691&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402160089510133&p=691&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402160089509863&p=691&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402160089505576&p=721&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402160089505246&p=721&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402160089505027&p=721&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402160089503248&p=721&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402160089498859&p=721&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402160089497542&p=721&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402160089497479&p=721&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402160089495913&p=721&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402160089493663&p=721&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402160089493546&p=721&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402150089486139&p=721&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402150089485887&p=721&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=kakao.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402150089485110&p=721&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402150089480535&p=721&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402150089479752&p=721&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402150089477349&p=721&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402150089475192&p=721&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402150089473356&p=721&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402150089473335&p=721&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402150089473281&p=721&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402150089472669&p=721&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402150089471061&p=721&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402150089470995&p=721&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402150089470959&p=721&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402150089470803&p=721&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402150089470404&p=721&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402150089469789&p=721&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402150089469510&p=721&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402150089469489&p=721&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402150089467947&p=721&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402150089466759&p=751&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402140089457189&p=751&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402140089448264&p=751&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402140089448237&p=751&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402140089442675&p=751&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402140089439780&p=751&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402140089439474&p=751&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402140089438874&p=751&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402140089438607&p=751&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402140089438040&p=751&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402140089437845&p=751&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402140089437689&p=751&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402140089434506&p=751&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402140089433351&p=751&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402140089432142&p=751&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402130089423811&p=751&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402130089423769&p=751&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402130089423316&p=751&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402130089420571&p=751&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402130089420565&p=751&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402130089420412&p=751&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402130089420304&p=751&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402130089420292&p=751&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402130089419704&p=751&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402130089419245&p=751&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402130089419104&p=751&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402130089416575&p=751&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402130089416431&p=751&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402130089416245&p=751&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402130089414934&p=751&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402130089413890&p=781&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402130089413209&p=781&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402130089412036&p=781&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402130089411880&p=781&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402130089410347&p=781&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402120089406816&p=781&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402120089405409&p=781&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402120089405007&p=781&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402120089404650&p=781&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402120089402730&p=781&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402120089401224&p=781&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402120089395335&p=781&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402120089395098&p=781&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402120089395041&p=781&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402120089389524&p=781&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402120089389470&p=781&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402120089388360&p=781&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402110089382792&p=781&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402110089381724&p=781&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402110089380878&p=781&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402110089380323&p=781&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402110089379402&p=781&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402110089379306&p=781&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402110089376900&p=781&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402110089376018&p=781&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402110089372592&p=781&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402110089372454&p=781&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402100089366952&p=781&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402100089365593&p=781&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402100089365011&p=781&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402100089364096&p=811&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402100089362608&p=811&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402100089361972&p=811&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402100089361555&p=811&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402100089360667&p=811&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402100089359857&p=811&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402100089359422&p=811&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402100089358222&p=811&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402100089357706&p=811&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402100089357298&p=811&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402100089355729&p=811&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402100089355168&p=811&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402100089354904&p=811&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402100089353356&p=811&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402090089350332&p=811&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402090089350050&p=811&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402090089347674&p=811&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402090089346951&p=811&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402090089346423&p=811&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402090089345163&p=811&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=naver.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402090089343435&p=811&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402090089343255&p=811&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402090089342805&p=811&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402090089342724&p=811&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402090089342700&p=811&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402090089342547&p=811&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402090089342379&p=811&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402090089342238&p=811&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402090089342013&p=811&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402090089341881&p=811&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402090089339625&p=841&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402090089338788&p=841&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# https://mlbpark.donga.com/mp/b.php?id=202402090089338302&p=841&b=kbotown&m=view&select=spf&query=%EB%91%90%EC%82%B0&subselect=sct&subquery=&user=&site=donga.com 완료
# Error sending stats to Plausible: error sending request for url (https://plausible.io/api/event): error trying to connect: dns error: 알려진 호스트가 없습니다. (os error 11001)
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# Cell In[5], line 139
#     136 save_to_file()
#     138 # 게시글 정보 크롤링 및 저장
# --> 139 get_contents(post_links)
#
# Cell In[5], line 87, in get_contents(posts)
#      85 def get_contents(posts):
#      86     for post_link in posts:
# ---> 87         content = extract_info(post_link)
#      88         append_to_file(f"MLBPARK_{QUERY}_0228.csv", content)
#      89     return print("모든 작업이 완료되었습니다.")
#
# Cell In[5], line 51, in extract_info(url)
#      49 chrome_options.add_argument('--headless')  # Headless 모드 활성화
#      50 driver = webdriver.Chrome(options=chrome_options)
# ---> 51 driver.get(url)
#      52 driver.get(url)
#      53 html = driver.page_source
#
# File ~\anaconda3\envs\new\lib\site-packages\selenium\webdriver\remote\webdriver.py:356, in WebDriver.get(self, url)
#     354 def get(self, url: str) -> None:
#     355     """Loads a web page in the current browser session."""
# --> 356     self.execute(Command.GET, {"url": url})
#
# File ~\anaconda3\envs\new\lib\site-packages\selenium\webdriver\remote\webdriver.py:347, in WebDriver.execute(self, driver_command, params)
#     345 response = self.command_executor.execute(driver_command, params)
#     346 if response:
# --> 347     self.error_handler.check_response(response)
#     348     response["value"] = self._unwrap_value(response.get("value", None))
#     349     return response
#
# File ~\anaconda3\envs\new\lib\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# WebDriverException: Message: unknown error: net::ERR_INTERNET_DISCONNECTED
#   (Session info: chrome-headless-shell=122.0.6261.95)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF7BE61AD22+56930]
# 	(No symbol) [0x00007FF7BE58F622]
# 	(No symbol) [0x00007FF7BE4442E5]
# 	(No symbol) [0x00007FF7BE44011A]
# 	(No symbol) [0x00007FF7BE4329F4]
# 	(No symbol) [0x00007FF7BE433D29]
# 	(No symbol) [0x00007FF7BE432CF3]
# 	(No symbol) [0x00007FF7BE431EF4]
# 	(No symbol) [0x00007FF7BE431E11]
# 	(No symbol) [0x00007FF7BE430625]
# 	(No symbol) [0x00007FF7BE430EDC]
# 	(No symbol) [0x00007FF7BE4469FD]
# 	(No symbol) [0x00007FF7BE4C8B47]
# 	(No symbol) [0x00007FF7BE4ABC9A]
# 	(No symbol) [0x00007FF7BE4C81E2]
# 	(No symbol) [0x00007FF7BE4ABA43]
# 	(No symbol) [0x00007FF7BE47D438]
# 	(No symbol) [0x00007FF7BE47E4D1]
# 	GetHandleVerifier [0x00007FF7BE996AAD+3709933]
# 	GetHandleVerifier [0x00007FF7BE9EFFED+4075821]
# 	GetHandleVerifier [0x00007FF7BE9E817F+4043455]
# 	GetHandleVerifier [0x00007FF7BE6B9756+706710]
# 	(No symbol) [0x00007FF7BE59B8FF]
# 	(No symbol) [0x00007FF7BE596AE4]
# 	(No symbol) [0x00007FF7BE596C3C]
# 	(No symbol) [0x00007FF7BE5868F4]
# 	BaseThreadInitThunk [0x00007FFE20BE7344+20]
# 	RtlUserThreadStart [0x00007FFE212E26B1+33]

# %%
import pandas as pd
test = pd.read_csv('MLBPARK_.csv')
test
# Out:
#        site                   title user_id            post_time  \
# 0     엠엘비파크         두산최종인 허벅지가 ㅎ ㄷㄷ   두산임종성  2024-02-27 15:32:00
# 1     엠엘비파크     두산최종인선수 스위퍼 한번 보여줘요    D김택연  2024-02-27 15:29:00
# 2     엠엘비파크  두산김재환은 연습경기 한경기도 안나왔죠?   두산임종성  2024-02-27 15:27:00
# 3     엠엘비파크  두산김재환은 연습경기 한경기도 안나왔죠?   두산임종성  2024-02-27 15:27:00
# 4     엠엘비파크  두산김재환은 연습경기 한경기도 안나왔죠?   두산임종성  2024-02-27 15:27:00
# ...     ...                     ...     ...                  ...
# 6438  엠엘비파크         두산올해 두산 선수들 기대치   두산최준호  2024-01-06 19:00:00
# 6439  엠엘비파크         두산올해 두산 선수들 기대치   두산최준호  2024-01-06 19:00:00
# 6440  엠엘비파크         두산올해 두산 선수들 기대치   두산최준호  2024-01-06 19:00:00
# 6441  엠엘비파크         두산올해 두산 선수들 기대치   두산최준호  2024-01-06 19:00:00
# 6442  엠엘비파크         두산올해 두산 선수들 기대치   두산최준호  2024-01-06 19:00:00
#
#                                                    post view_cnt recomm_cnt  \
# 0                            상체에 비해 허벅지가 엄청 굵네요.ㅎㄷㄷ추천공유      195          0
# 1                                   얼마나 잘던지나 보게  ㅎㅎ추천공유      108          0
# 2                         부상인지. 강정호레슨 받은 스윙 폼 보고싶은데추천공유      658          0
# 3                         부상인지. 강정호레슨 받은 스윙 폼 보고싶은데추천공유      658          0
# 4                         부상인지. 강정호레슨 받은 스윙 폼 보고싶은데추천공유      658          0
# ...                                                 ...      ...        ...
# 6438  ‌1. 정수빈 2할 9푼 30도루 우르크 1102. 허경민 2할 8푼 우르크 110...     1449          0
# 6439  ‌1. 정수빈 2할 9푼 30도루 우르크 1102. 허경민 2할 8푼 우르크 110...     1449          0
# 6440  ‌1. 정수빈 2할 9푼 30도루 우르크 1102. 허경민 2할 8푼 우르크 110...     1449          0
# 6441  ‌1. 정수빈 2할 9푼 30도루 우르크 1102. 허경민 2할 8푼 우르크 110...     1449          0
# 6442  ‌1. 정수빈 2할 9푼 30도루 우르크 1102. 허경민 2할 8푼 우르크 110...     1449          0
#
#      reply_cnt reply_author                                  reply_content
# 0            0          NaN                                            NaN
# 1            0          NaN                                            NaN
# 2            3        28최승용                            청백전 연습경기 한타석도 안나왔어요
# 3            3        두산임종성                         28최승용// 웬지 부상같은데 불안하네요
# 4            3          아할라                                        청백전때 나옴
# ...        ...          ...                                            ...
# 6438        13     gg...re?      투수는 승수빼고 저 성적 가능한데, 타자는 진짜 우주의 기운 끌어야 가능.
# 6439        13       mvp여동건                           주전 야수 7명이 두자릿수 홈런...
# 6440        13       mvp여동건                           저기에 김택연 25세이브면 완벽하네요
# 6441        13         DB82  알칸타라 그대로 가기로 했나 보군요 솔직히 타자는 새로운 인물이 나와줬음 좋겠는데
# 6442        13         스페셜러        저기서 가을야구 못 가려면 불펜이 80경기는 역전패로 날려먹어야....
#
# [6443 rows x 10 columns]

# %%
import pandas as pd
a = pd.read_csv('MLBPARK_20240227-0305.csv')
a
# Out:
#        site                                              title user_id  \
# 0     엠엘비파크                                두산김재환 부상이면 언제 복귀할까요   이거나원참
# 1     엠엘비파크                                두산김재환 부상이면 언제 복귀할까요   이거나원참
# 2     엠엘비파크                                두산김재환 부상이면 언제 복귀할까요   이거나원참
